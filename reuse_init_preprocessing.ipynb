# %% [markdown]
# # Yelp Data Preprocessing

# %%
import pandas as pd
import os
import glob
import json
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('seaborn')

path = '/Users/Prayerest_/PycharmProjects/yelp/yelp_dataset/'

file_business, file_checkin, file_review, file_tip, file_user = [
    'business.json',
    'checkin.json',
    'review.json',
    'tip.json',
    'user.json'
]

# %% [markdown]
# # Business

# %%
with open(file_business) as f:
    df_business = pd.DataFrame(json.loads(line) for line in f)
df_business.head(2)
# Out:
#                        address  \
# 0  2818 E Camino Acequia Drive
# 1         30 Eglinton Avenue W
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsPriceRange2': '2', 'GoodForMeal':...  QXAEGFB4oINsVuTFxEYKFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Wednesday': '9:0-0:0', ...        1  43.605499
#
#     longitude                        name postal_code  review_count  stars  \
# 0 -112.018481  Arizona Biltmore Golf Club       85016             5    3.0
# 1  -79.652289  Emerald Chinese Restaurant     L5R 3E7           128    2.5
#
#   state
# 0    AZ
# 1    ON

# %%
dict(df_business[:1])
# Out:
# {'address': 0    2818 E Camino Acequia Drive
#  Name: address, dtype: object, 'attributes': 0    {'GoodForKids': 'False'}
#  Name: attributes, dtype: object, 'business_id': 0    1SWheh84yJXfytovILXOAQ
#  Name: business_id, dtype: object, 'categories': 0    Golf, Active Life
#  Name: categories, dtype: object, 'city': 0    Phoenix
#  Name: city, dtype: object, 'hours': 0    None
#  Name: hours, dtype: object, 'is_open': 0    0
#  Name: is_open, dtype: int64, 'latitude': 0    33.522143
#  Name: latitude, dtype: float64, 'longitude': 0   -112.018481
#  Name: longitude, dtype: float64, 'name': 0    Arizona Biltmore Golf Club
#  Name: name, dtype: object, 'postal_code': 0    85016
#  Name: postal_code, dtype: object, 'review_count': 0    5
#  Name: review_count, dtype: int64, 'stars': 0    3.0
#  Name: stars, dtype: float64, 'state': 0    AZ
#  Name: state, dtype: object}

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192609 entries, 0 to 192608
# Data columns (total 14 columns):
# address         192609 non-null object
# attributes      163773 non-null object
# business_id     192609 non-null object
# categories      192127 non-null object
# city            192609 non-null object
# hours           147779 non-null object
# is_open         192609 non-null int64
# latitude        192609 non-null float64
# longitude       192609 non-null float64
# name            192609 non-null object
# postal_code     192609 non-null object
# review_count    192609 non-null int64
# stars           192609 non-null float64
# state           192609 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 20.6+ MB

# %%
df_business['city'].value_counts().head(10)
# Out:
# Las Vegas     29370
# Toronto       18906
# Phoenix       18766
# Charlotte      9509
# Scottsdale     8837
# Calgary        7736
# Pittsburgh     7017
# Montréal       6449
# Mesa           6080
# Henderson      4892
# Name: city, dtype: int64

# %%
df_business['state'].value_counts().head(10)
# Out:
# AZ    56686
# NV    36312
# ON    33412
# NC    14720
# OH    14697
# PA    11216
# QC     9219
# AB     8012
# WI     5154
# IL     1932
# Name: state, dtype: int64

# %%
condition1 = df_business['city'] == 'Las Vegas'
df_filtered = df_business[condition1]
df_filtered = df_filtered.dropna(subset=['categories'], how='all')
condition2 = df_filtered.categories.apply(lambda x: 'Restaurants' in x)
df_filtered = df_filtered[condition2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6450 entries, 17 to 192562
# Data columns (total 14 columns):
# address         6450 non-null object
# attributes      6294 non-null object
# business_id     6450 non-null object
# categories      6450 non-null object
# city            6450 non-null object
# hours           5004 non-null object
# is_open         6450 non-null int64
# latitude        6450 non-null float64
# longitude       6450 non-null float64
# name            6450 non-null object
# postal_code     6450 non-null object
# review_count    6450 non-null int64
# stars           6450 non-null float64
# state           6450 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 755.9+ KB

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6450 entries, 17 to 192562
# Data columns (total 14 columns):
# address         6450 non-null object
# attributes      6294 non-null object
# business_id     6450 non-null object
# categories      6450 non-null object
# city            6450 non-null object
# hours           5004 non-null object
# is_open         6450 non-null int64
# latitude        6450 non-null float64
# longitude       6450 non-null float64
# name            6450 non-null object
# postal_code     6450 non-null object
# review_count    6450 non-null int64
# stars           6450 non-null float64
# state           6450 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 755.9+ KB

# %%
df_filtered.head()
# Out:
#                               address  \
# 17       1775 E Tropicana Ave, Ste 29
# 25              6055 E Lake Mead Blvd
# 75            6125 Spring Mountain Rd
# 111                  4343 N Rancho Dr
# 135  Artisan Hotel, 1501 W Sahara Ave
#
#                                             attributes  \
# 17   {'BusinessAcceptsCreditCards': 'True', 'BYOBCo...
# 25   {'BusinessAcceptsCreditCards': 'True', 'HasTV'...
# 75   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 111                                               None
# 135  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                 business_id  \
# 17   PZ-LZzSlhSe9utkQYU8pFg
# 25   tstimHoMcYbkSC4eBA1wEg
# 75   kANF0dbeoW34s2vwh6Umfw
# 111  X8mtoSxY8whtmbDlj0D3Aw
# 135  bJP4l_BGq2CudEu0m-wNjg
#
#                                             categories       city  \
# 17                                Restaurants, Italian  Las Vegas
# 25   Mexican, Restaurants, Patisserie/Cake Shop, Fo...  Las Vegas
# 75   Fast Food, Food, Restaurants, Ice Cream & Froz...  Las Vegas
# 111                               Restaurants, Chinese  Las Vegas
# 135        Restaurants, Pizza, Italian, American (New)  Las Vegas
#
#                                                  hours  is_open   latitude  \
# 17                                                None        0  36.100016
# 25   {'Monday': '11:0-21:0', 'Wednesday': '10:0-21:...        1  36.195615
# 75                                                None        0  36.125031
# 111                                               None        1  36.238596
# 135  {'Monday': '16:0-0:0', 'Wednesday': '16:0-0:0'...        0  36.143672
#
#       longitude                                 name postal_code  \
# 17  -115.128529           Carluccio's Tivoli Gardens       89119
# 25  -115.040529  Maria's Mexican Restaurant & Bakery       89156
# 75  -115.225620                          Dairy Queen       89146
# 111 -115.233331                Imperial Asian Buffet       89030
# 135 -115.169792             Artisan Fine Dining Room       89102
#
#      review_count  stars state
# 17             40    4.0    NV
# 25            184    4.5    NV
# 75             33    2.0    NV
# 111             4    2.0    NV
# 135             3    2.0    NV

# %%
df_filtered.to_csv("selected_business_all_info.csv",index=False)

# %%
con = df_filtered['business_id'] == '2hSIeCX2cV-chFcBBXrZZA'
df_filtered[con]
# Out:
#                               address  \
# 14633  6145 S Fort Apache Rd, Ste 506
#
#                                               attributes  \
# 14633  {'RestaurantsDelivery': 'False', 'BusinessAcce...
#
#                   business_id  \
# 14633  2hSIeCX2cV-chFcBBXrZZA
#
#                                               categories       city  \
# 14633  Organic Stores, Juice Bars & Smoothies, Coffee...  Las Vegas
#
#                                                    hours  is_open   latitude  \
# 14633  {'Monday': '6:30-16:0', 'Wednesday': '6:30-16:...        1  36.075943
#
#         longitude               name postal_code  review_count  stars state
# 14633 -115.298066  Pressed For Juice       89148           197    4.5    NV

# %%
selected_features = [u'business_id', u'name', u'categories', u'stars']
df_selected_business = df_filtered[selected_features]
df_selected_business.head()
# Out:
#                 business_id                                 name  \
# 17   PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 25   tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 75   kANF0dbeoW34s2vwh6Umfw                          Dairy Queen
# 111  X8mtoSxY8whtmbDlj0D3Aw                Imperial Asian Buffet
# 135  bJP4l_BGq2CudEu0m-wNjg             Artisan Fine Dining Room
#
#                                             categories  stars
# 17                                Restaurants, Italian    4.0
# 25   Mexican, Restaurants, Patisserie/Cake Shop, Fo...    4.5
# 75   Fast Food, Food, Restaurants, Ice Cream & Froz...    2.0
# 111                               Restaurants, Chinese    2.0
# 135        Restaurants, Pizza, Italian, American (New)    2.0

# %%
# Rename the column name "stars" to "avg_stars" to avoid naming conflicts with review dataset
df_selected_business.rename(columns={'stars': 'avg_stars'}, inplace = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_selected_business.head()
# Out:
#                 business_id                                 name  \
# 17   PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 25   tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 75   kANF0dbeoW34s2vwh6Umfw                          Dairy Queen
# 111  X8mtoSxY8whtmbDlj0D3Aw                Imperial Asian Buffet
# 135  bJP4l_BGq2CudEu0m-wNjg             Artisan Fine Dining Room
#
#                                             categories  avg_stars
# 17                                Restaurants, Italian        4.0
# 25   Mexican, Restaurants, Patisserie/Cake Shop, Fo...        4.5
# 75   Fast Food, Food, Restaurants, Ice Cream & Froz...        2.0
# 111                               Restaurants, Chinese        2.0
# 135        Restaurants, Pizza, Italian, American (New)        2.0

# %%
# Save to ./data/selected_business.csv
df_selected_business.to_csv('selected_business.csv', encoding='utf-8', index = False)

# %%
# check reload
df_selected_business_reload = pd.read_csv('selected_business.csv')
df_selected_business_reload.head()
# Out:
#               business_id                                 name  \
# 0  PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 1  tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 2  kANF0dbeoW34s2vwh6Umfw                          Dairy Queen
# 3  X8mtoSxY8whtmbDlj0D3Aw                Imperial Asian Buffet
# 4  bJP4l_BGq2CudEu0m-wNjg             Artisan Fine Dining Room
#
#                                           categories  avg_stars
# 0                               Restaurants, Italian        4.0
# 1  Mexican, Restaurants, Patisserie/Cake Shop, Fo...        4.5
# 2  Fast Food, Food, Restaurants, Ice Cream & Froz...        2.0
# 3                               Restaurants, Chinese        2.0
# 4        Restaurants, Pizza, Italian, American (New)        2.0

# %% [markdown]
# # Review

# %%
with open(file_review) as f:
    df_review = pd.DataFrame(json.loads(line) for line in f)
df_review.head(2)
# Out:
#               business_id  cool                 date  funny  \
# 0  ujmEBvifdJM6h6RLv4wQIg     0  2013-05-07 04:34:36      1
# 1  NZnhc2sEQy3RmzKTZnqtwQ     0  2017-01-14 21:30:33      0
#
#                 review_id  stars  \
# 0  Q1sbwvVQXV2734tPgoKj4Q    1.0
# 1  GJXCdrto3ASJOqKeVWPi6Q    5.0
#
#                                                 text  useful  \
# 0  Total bill for this horrible service? Over $8G...       6
# 1  I *adore* Travis at the Hard Rock's new Kelly ...       0
#
#                   user_id
# 0  hG7b0MtEbXx5QzbzE6C_VA
# 1  yXQM5uF2jS6es16SJzNHfg

# %% [markdown]
# #### Use the "business_id" column to filter review data

# %%
# Prepare the business dataframe and set index to column "business_id", and name it as df_left
df_selected_business = df_selected_business.set_index('business_id')
df_selected_business.index.names = ['df_left']
# Prepare the review dataframe and set index to column "business_id", and name it as df_right
df_review = df_review.set_index('business_id')
df_review.index.names = ['df_right']
# Join df_left and df_right.
df_joined = df_selected_business.join(df_review)
df_joined.head()
# Reset index
df_joined_reset = df_joined.reset_index()
df_joined_reset.head()
df_joined_reset.rename(columns={'index': 'business_id'}, inplace = True)
df_joined_reset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1242711 entries, 0 to 1242710
# Data columns (total 12 columns):
# business_id    1242711 non-null object
# name           1242711 non-null object
# categories     1242711 non-null object
# avg_stars      1242711 non-null float64
# cool           1242711 non-null int64
# date           1242711 non-null object
# funny          1242711 non-null int64
# review_id      1242711 non-null object
# stars          1242711 non-null float64
# text           1242711 non-null object
# useful         1242711 non-null int64
# user_id        1242711 non-null object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 113.8+ MB

# %%
df_joined_reset = df_joined.reset_index()
df_joined_reset.rename(columns={'index': 'business_id'}, inplace = True)

# %%
df_joined_reset.to_csv('joined_business_review_all.csv', encoding='utf-8', index = False)

# %%
#df_joined_reset = pd.read_csv('joined_business_review_all.csv')

# %%
df_joined_reset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242711 entries, SFftbQSwHZ24ahhfj5vVxQ to 6Aqot7bwAqkrcfGsRk8HIw
# Data columns (total 11 columns):
# business_id    1242711 non-null object
# name           1242711 non-null object
# categories     1242711 non-null object
# avg_stars      1242711 non-null float64
# cool           1242711 non-null int64
# date           1242711 non-null datetime64[ns]
# funny          1242711 non-null int64
# review_id      1242711 non-null object
# stars          1242711 non-null float64
# text           1242711 non-null object
# useful         1242711 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 113.8+ MB

# %%
df_joined_reset['date'] = pd.to_datetime(df_joined_reset['date'])

# %%
df_joined_reset['date'].hist(bins=30)

# %%
max(df_joined_reset['date'])
# Out:
# Timestamp('2018-11-14 18:12:40')

# %%
min(df_joined_reset['date'])
# Out:
# Timestamp('2005-01-24 22:21:29')

# %%
df_joined_reset.groupby('user_id').agg('count').name.describe()
# Out:
# count    439163.000000
# mean          2.829726
# std           8.098200
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        1382.000000
# Name: name, dtype: float64

# %%
df_joined_reset['avg_stars'].hist(bins=40)

# %%
df_joined_reset['stars'].hist(bins=40)

# %%
df_joined_reset['name'].value_counts().head(10).plot.bar()

# %%
user_select = df_joined_reset['user_id'].value_counts()
df_joined_reset = df_joined_reset.set_index('user_id')
df_selected = df_joined_reset[user_select > 10]
df_selected_reset = df_selected.reset_index()
df_selected_reset.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                   user_id             business_id                  name  \
# 0  n_HMBasYWRQxVjts_QyF9w  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 1  tXhscxwFTd-ayLTdPx_2yA  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 2  y4O_c6UUAAtPb3Uk-T4t8A  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 3  _0Za7N9v4rcUVxHy107a7Q  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 4  aZg019PkWURjSnC7-CH0Bw  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                         categories  avg_stars  cool  \
# 0  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 1  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 2  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 3  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 4  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
#
#                   date  funny               review_id  stars  \
# 0  2014-03-14 04:56:09      0  7H98TWCrkyRxo8DMfYrWRA    5.0
# 1  2012-05-28 15:40:38      1  jTlP9izKAXbF9T91pbP7RA    3.0
# 2  2017-08-16 06:41:49      0  WYNusZjgf6BsISk829MQKw    5.0
# 3  2015-11-18 21:41:50      0  cHsv7KZDouejMVih43qRUQ    5.0
# 4  2013-05-29 07:23:34      0  CVkTL2dfXOdtpMeFhtWayw    5.0
#
#                                                 text  useful
# 0  this place hasnt change a bit in their service...       0
# 1  I've eaten here twice, it was better a few yea...       0
# 2  A great culinary experience from start to fini...       0
# 3  Had Dinner at Delmonico on 11-5-15.  Still the...       0
# 4  My wife took me here for a fabulous dinner bef...       0

# %%
df_item = df_selected_reset

# %%
df_item.head()
# Out:
#                   user_id             business_id                  name  \
# 0  n_HMBasYWRQxVjts_QyF9w  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 1  tXhscxwFTd-ayLTdPx_2yA  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 2  y4O_c6UUAAtPb3Uk-T4t8A  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 3  _0Za7N9v4rcUVxHy107a7Q  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 4  aZg019PkWURjSnC7-CH0Bw  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                         categories  avg_stars  cool  \
# 0  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 1  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 2  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 3  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 4  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
#
#                   date  funny               review_id  stars  \
# 0  2014-03-14 04:56:09      0  7H98TWCrkyRxo8DMfYrWRA    5.0
# 1  2012-05-28 15:40:38      1  jTlP9izKAXbF9T91pbP7RA    3.0
# 2  2017-08-16 06:41:49      0  WYNusZjgf6BsISk829MQKw    5.0
# 3  2015-11-18 21:41:50      0  cHsv7KZDouejMVih43qRUQ    5.0
# 4  2013-05-29 07:23:34      0  CVkTL2dfXOdtpMeFhtWayw    5.0
#
#                                                 text  useful
# 0  this place hasnt change a bit in their service...       0
# 1  I've eaten here twice, it was better a few yea...       0
# 2  A great culinary experience from start to fini...       0
# 3  Had Dinner at Delmonico on 11-5-15.  Still the...       0
# 4  My wife took me here for a fabulous dinner bef...       0

# %%
item_select = df_item['business_id'].value_counts()
df_item_set = df_item.set_index('business_id')
df_selected_item = df_item_set[item_select > 10]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_item_reset = df_selected_item.reset_index()
df_item_reset.head()
# Out:
#               business_id                 user_id                  name  \
# 0  --9e1ONYQuAa-CB_Rrw7Tw  n_HMBasYWRQxVjts_QyF9w  Delmonico Steakhouse
# 1  --9e1ONYQuAa-CB_Rrw7Tw  tXhscxwFTd-ayLTdPx_2yA  Delmonico Steakhouse
# 2  --9e1ONYQuAa-CB_Rrw7Tw  y4O_c6UUAAtPb3Uk-T4t8A  Delmonico Steakhouse
# 3  --9e1ONYQuAa-CB_Rrw7Tw  _0Za7N9v4rcUVxHy107a7Q  Delmonico Steakhouse
# 4  --9e1ONYQuAa-CB_Rrw7Tw  aZg019PkWURjSnC7-CH0Bw  Delmonico Steakhouse
#
#                                         categories  avg_stars  cool  \
# 0  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 1  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 2  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 3  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 4  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
#
#                   date  funny               review_id  stars  \
# 0  2014-03-14 04:56:09      0  7H98TWCrkyRxo8DMfYrWRA    5.0
# 1  2012-05-28 15:40:38      1  jTlP9izKAXbF9T91pbP7RA    3.0
# 2  2017-08-16 06:41:49      0  WYNusZjgf6BsISk829MQKw    5.0
# 3  2015-11-18 21:41:50      0  cHsv7KZDouejMVih43qRUQ    5.0
# 4  2013-05-29 07:23:34      0  CVkTL2dfXOdtpMeFhtWayw    5.0
#
#                                                 text  useful
# 0  this place hasnt change a bit in their service...       0
# 1  I've eaten here twice, it was better a few yea...       0
# 2  A great culinary experience from start to fini...       0
# 3  Had Dinner at Delmonico on 11-5-15.  Still the...       0
# 4  My wife took me here for a fabulous dinner bef...       0

# %%
df_item_reset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414453 entries, 0 to 414452
# Data columns (total 12 columns):
# business_id    414453 non-null object
# user_id        414453 non-null object
# name           414453 non-null object
# categories     414453 non-null object
# avg_stars      414453 non-null float64
# cool           414453 non-null int64
# date           414453 non-null object
# funny          414453 non-null int64
# review_id      414453 non-null object
# stars          414453 non-null float64
# text           414453 non-null object
# useful         414453 non-null int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 37.9+ MB

# %%
len(df_item_reset.business_id.unique())
# Out:
# 4218

# %%
len(df_item_reset.user_id.unique())
# Out:
# 16255

# %%
df_item_reset.groupby('user_id').agg('count').name.describe()
# Out:
# count    16255.000000
# mean        25.496955
# std         32.502660
# min          5.000000
# 25%         13.000000
# 50%         16.000000
# 75%         26.000000
# max       1270.000000
# Name: name, dtype: float64

# %%
df_item_reset.groupby('user_id').agg('count').min()
# Out:
# business_id    5
# name           5
# categories     5
# avg_stars      5
# cool           5
# date           5
# funny          5
# review_id      5
# stars          5
# text           5
# useful         5
# dtype: int64

# %%
df_item_reset.groupby('business_id').agg('count').min()
# Out:
# user_id       11
# name          11
# categories    11
# avg_stars     11
# cool          11
# date          11
# funny         11
# review_id     11
# stars         11
# text          11
# useful        11
# dtype: int64

# %%
user_select_2 = df_item_reset['user_id'].value_counts()
df_item_reset_2 = df_item_reset.set_index('user_id')
df_selected_user_2 = df_item_reset_2[user_select_2 > 10]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_item_reset_2 = df_selected_user_2.reset_index()
df_item_reset_2.head()
# Out:
#                   user_id             business_id                  name  \
# 0  n_HMBasYWRQxVjts_QyF9w  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 1  tXhscxwFTd-ayLTdPx_2yA  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 2  y4O_c6UUAAtPb3Uk-T4t8A  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 3  _0Za7N9v4rcUVxHy107a7Q  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 4  aZg019PkWURjSnC7-CH0Bw  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                         categories  avg_stars  cool  \
# 0  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 1  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 2  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 3  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 4  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
#
#                   date  funny               review_id  stars  \
# 0  2014-03-14 04:56:09      0  7H98TWCrkyRxo8DMfYrWRA    5.0
# 1  2012-05-28 15:40:38      1  jTlP9izKAXbF9T91pbP7RA    3.0
# 2  2017-08-16 06:41:49      0  WYNusZjgf6BsISk829MQKw    5.0
# 3  2015-11-18 21:41:50      0  cHsv7KZDouejMVih43qRUQ    5.0
# 4  2013-05-29 07:23:34      0  CVkTL2dfXOdtpMeFhtWayw    5.0
#
#                                                 text  useful
# 0  this place hasnt change a bit in their service...       0
# 1  I've eaten here twice, it was better a few yea...       0
# 2  A great culinary experience from start to fini...       0
# 3  Had Dinner at Delmonico on 11-5-15.  Still the...       0
# 4  My wife took me here for a fabulous dinner bef...       0

# %%
con = df_item_reset_2['business_id'] == '2hSIeCX2cV-chFcBBXrZZA'
df_item_reset_2[con]
# Out:
#                       user_id             business_id               name  \
# 10969  w1uEa7272-ZXdiTm0aDM8A  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10970  Apj8bnqWlnaiSu4YDl0wDA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10971  _UUmslYG8Y-IYFf8rHl0Ww  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10972  7YWkpjUb-YWbfpN7d7sRqg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10973  cFGAElozHTdQDfHimOiSBQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10974  fQ9owsz3ap05vrGrTLPa4Q  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10975  oK1v-yP9ygKWg6M19wWYIQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10976  Jiw8Gd0ZCekHBDK74fyHMg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10977  fS86t0IvNj-kDBae2mJHSQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10978  ZiO2Wr41kZ4Vz64aheBFPQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10979  _QazmMfEfX6lcpMH2Qmcjg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10980  kTny8RFBPj9du2aIRb8V0A  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10981  DuSuoUQwsXjgvvslwfsL3g  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10982  4k1d_QuXtkRVaFPDtaGgbA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10983  5OllWsrKJsYo3XQK6siRKA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10984  -JvZ2KzL8VCkQI1ZHVrCow  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10985  WgbocVhRcRXHwVyi9kfI4w  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10986  1dWLN4Mr4hKhu8MQUCKqXQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10987  ssgRnGGXxigWTEXM-n92lg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10988  o-B9uwfa1RDJ4QCO0yzYXA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10989  7L8utEpYiVj3pNNjZkQaLQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10990  WXA_4WVO1tpD0So3pZOQQQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10991  FcWu03iLuGYGHbFXO556pA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10992  L3DxG0n3lRq5N2lv1QNrrA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10993  fQ9owsz3ap05vrGrTLPa4Q  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10994  1PvDk9-siiBuDSt73Jgi-Q  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10995  xTimtxT3p1zKrtfP9JRuZA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10996  6tYvKMhqiRRWjg3AVARCQQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10997  abzIJZ1HBSsCh3X7xUAZ0w  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 10998  xymN6nkSGPL4A2D3C2DuaQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# ...                       ...                     ...                ...
# 11001  fquTEV93jh82JYob6u0CEA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11002  W_pPF_bKVNtA8m7lRqdZdw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11003  uNuPyXHbbtHnhWhPLamESQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11004  kzRq4H_nSf4b3F_sdymWSw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11005  Xo21rD8CKk0gJFffjod1zQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11006  kzRq4H_nSf4b3F_sdymWSw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11007  cFGAElozHTdQDfHimOiSBQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11008  hCy4Kkyo4N0fFLMDpKjYyw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11009  WM7MFrRP-7YFuGBAJ6quRQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11010  4TDIYnzB4qfBsmP4RWapZQ  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11011  kzRq4H_nSf4b3F_sdymWSw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11012  CZs1Eq7t1fqpXV1yox-CVg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11013  eMOpOLfR1Zz5tfHUlzMp_w  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11014  bzU8Cl6B9nqV1i5NReobvw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11015  PqpLCIytJhnLE_xOKQs1Dg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11016  tnSVm_tdM5zthKgmGF5d1A  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11017  fcra9uhtCHmpXdhDamb5cg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11018  yNH3Z0MvqpjXq1NbFsDLFg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11019  _0sr_IIJ6kMDAYwQBCtIgA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11020  LoycNCjl1uFoQRV0pCwanA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11021  rcaeJEmZyT305cFXlTsiig  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11022  3zuiM8dt9bq-1oHjpiEfrg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11023  fLNmJ6hk0OgfTpUMXeSusA  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11024  bLbSNkLggFnqwNNzzq-Ijw  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11025  IMguz1Z9dp8HG0UfeLEdEg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11026  3Qv2rjPXC2eNKyV5lh3J_g  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11027  DoxlwKliGyLiyWoN0akO0g  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11028  U2Zysz5TsKftsETEdq7J0g  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11029  -JvZ2KzL8VCkQI1ZHVrCow  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
# 11030  zuJwiAXFGQ4_Dfozybx5kg  2hSIeCX2cV-chFcBBXrZZA  Pressed For Juice
#
#                                               categories  avg_stars  cool  \
# 10969  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10970  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 10971  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 10972  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10973  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     2
# 10974  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10975  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10976  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     4
# 10977  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10978  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10979  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10980  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10981  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10982  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 10983  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     7
# 10984  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10985  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10986  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     6
# 10987  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10988  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10989  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 10990  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     2
# 10991  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 10992  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     3
# 10993  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10994  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10995  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10996  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 10997  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 10998  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# ...                                                  ...        ...   ...
# 11001  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 11002  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     5
# 11003  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11004  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     5
# 11005  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 11006  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     7
# 11007  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     2
# 11008  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11009  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11010  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11011  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     3
# 11012  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11013  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11014  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     5
# 11015  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 11016  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     5
# 11017  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 11018  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11019  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11020  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11021  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11022  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11023  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11024  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5    13
# 11025  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     1
# 11026  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     8
# 11027  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     3
# 11028  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     4
# 11029  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
# 11030  Organic Stores, Juice Bars & Smoothies, Coffee...        4.5     0
#
#                      date  funny               review_id  stars  \
# 10969 2016-05-31 10:53:47      0  ej_Bo4_WfYx_5NdfJnLHQQ    5.0
# 10970 2015-05-26 11:28:20      1  AeTukpOGdVe3rGGck7_x6g    5.0
# 10971 2015-04-29 05:11:04      0  A8meHAtEv1tFgWHcuwucXA    5.0
# 10972 2017-07-08 22:33:36      0  sLNMVyhyd-FtiCiTXEzOvg    5.0
# 10973 2016-10-14 05:40:15      1  NM9T5SEBTlpyuDmpQWnDAg    3.0
# 10974 2016-06-12 17:26:06      0  uXm7_kgJldDWKmKPLZpvzw    5.0
# 10975 2017-07-29 15:47:32      0  dUdvCuydmA9ysPw2S609Sw    3.0
# 10976 2016-03-18 22:49:40      2  RylPqItjM8Bw2jh0uHlIrw    5.0
# 10977 2015-07-16 22:14:21      0  P3h-yboIdFkshEBqHRo4EQ    5.0
# 10978 2016-11-23 00:06:37      0  L0Y2QtQkF97t7HhjJKHyDQ    5.0
# 10979 2016-01-18 08:03:27      0  gZvv9KSmt_lwBNp3IKyMpQ    5.0
# 10980 2018-02-11 18:27:46      0  JPojyDnobNye-W5CJZ72dw    5.0
# 10981 2018-02-02 04:37:57      0  EuEEMT9zGLvwdgVUK49jkg    3.0
# 10982 2015-08-08 05:25:23      0  aebx7eUNJBxOxbfiC8cTPA    4.0
# 10983 2016-10-15 15:44:20      5  IT0NibJf3-JEQrhHqYFjXw    5.0
# 10984 2017-05-27 13:37:39      0  YkDHyh1weoXDqz2LSrbpwg    5.0
# 10985 2016-03-08 02:51:03      0  u51jSQH6TFPngsXpF8H1bA    5.0
# 10986 2015-09-02 21:46:10      2  BLRYJ4PlZLQNGkwFD5lfGQ    5.0
# 10987 2015-04-03 21:28:52      0  dnDEfdkxUE7eBXtzcqe6lQ    5.0
# 10988 2018-07-10 18:44:50      0  xqlbF826lUjBG831eHH2SA    4.0
# 10989 2016-11-25 19:05:40      1  TIwZrA_yOMD9VXPkpof2wA    5.0
# 10990 2017-07-10 02:59:28      0  -QddBrZTKudv8NEXVref5A    5.0
# 10991 2017-10-27 22:22:26      1  iY6j4TsVyMcwIdKlXrmz0g    5.0
# 10992 2016-04-14 23:56:56      1  9xzBr6yEB6w7nBhqkkymqA    5.0
# 10993 2016-10-29 22:34:54      0  lDhJmKSxSPyjw6pJx8Vxrw    5.0
# 10994 2017-12-08 01:17:02      0  34EwswVCaIEEsRJiQwARuw    5.0
# 10995 2018-03-18 18:21:53      0  hlxWJPpd436M7GfGBKmd8Q    2.0
# 10996 2016-01-21 21:39:17      0  VRcymdC3npOCD0wAT_qo3g    5.0
# 10997 2016-09-09 19:42:42      0  DBYPLtqOKSv6RL1g73XdRg    4.0
# 10998 2018-08-28 00:31:17      0  J749jiDQbcCyp9ollhB9eg    5.0
# ...                   ...    ...                     ...    ...
# 11001 2018-04-09 00:35:34      0  e5mdxsV7lGeYaPsi8u6yqg    5.0
# 11002 2015-06-14 06:13:38      3  onXsfCBUuZT9zV8yDWbqFw    5.0
# 11003 2017-07-11 22:32:35      0  GcXJrjN_oe-HgutIwSB74w    4.0
# 11004 2015-11-27 15:59:59      3  4QH1xG-mCxyXZlHzxit7og    5.0
# 11005 2016-07-09 16:38:41      0  DIMacwe4m8zr_40WgYKtnA    5.0
# 11006 2015-09-30 12:52:21      4  wpYf6NM_cXwGRPBj8AUZeA    5.0
# 11007 2015-06-02 19:50:05      4  A3sS11CjkB7jIeEgO6Lf_Q    4.0
# 11008 2016-02-18 20:28:18      0  czcGriQMP-lNNMbAU6Jwvw    5.0
# 11009 2016-05-15 01:40:45      1  _91NjjRzjb83pF9vpirBVQ    5.0
# 11010 2015-04-12 19:53:54      0  cprLGSOYqctkXFkkjwnOSA    5.0
# 11011 2016-01-03 15:32:03      3  X692_wFJDe8sQO6CU7SQ1g    5.0
# 11012 2016-01-12 06:26:45      0  ptEDHkgZ59ZuYIV02Lqqlg    5.0
# 11013 2015-08-28 05:30:13      0  SbeNxVFqZyAkOQMGB_Kmfg    5.0
# 11014 2015-06-06 17:14:47      4  WCq0de27gcnMerb1aaVTvw    5.0
# 11015 2016-04-29 23:45:49      0  DtvbSxMJs1C0SCcxz3eHVQ    5.0
# 11016 2016-11-18 21:02:20      4  h1YcmE2TeB6pQO4OAbxOsQ    5.0
# 11017 2015-05-08 21:13:15      0  Fm6xHH92XSAZqwh_Fjml5A    5.0
# 11018 2017-01-10 21:22:01      0  yn_vmMbt0_b5wbPqcxFj1Q    5.0
# 11019 2015-06-29 21:31:40      0  TNyl6sXymrjAGTNSMJcntw    5.0
# 11020 2017-03-25 05:15:08      0  Pf8AdyNPitFd4ynisBVFSQ    5.0
# 11021 2016-05-06 04:10:31      0  8Ja6HI7yZ32QJ4AJs3x-pA    5.0
# 11022 2016-03-16 03:55:34      0  zw46YWqk16h9w5-7v-jEUw    5.0
# 11023 2016-08-21 23:18:30      0  iPZl_ldlqtl3WTD9iX4jJw    5.0
# 11024 2015-04-12 02:05:44      9  z32zlIa2b1otruWNjJUBCw    5.0
# 11025 2017-03-13 02:16:31      0  fkIWiKr4RwzGTbX0LmvVfA    5.0
# 11026 2016-05-06 00:04:17      6  ZHSSnjpPu27Hls1aKhNF3A    5.0
# 11027 2016-01-15 00:29:29      2  zyoG6UfpZUCphthjqacmmQ    5.0
# 11028 2015-03-31 15:37:12      1  Kf2uqT6XlKP-kSqKWd1DJw    5.0
# 11029 2017-03-26 21:54:55      0  VLKRJcfRKjvXR5EElWlF_w    5.0
# 11030 2018-07-07 10:08:06      0  2EFuVtZgXUtuqKc0MrtPqg    5.0
#
#                                                     text  useful
# 10969  I love this place! It's a little out of the wa...       0
# 10970  I love the modern design inside and very welco...       0
# 10971  This stuff is my crack.  I've been dodging my ...       3
# 10972  All I've tried from here was the Dos Leches nu...       0
# 10973  I finally decided to give this place a second ...       6
# 10974  Love this place ! #4 local hottie and the holy...       0
# 10975  I really really wanted to love this place, but...       1
# 10976  This place is the best in town. Everything fro...       3
# 10977  I got the Green Milk for myself and the Threes...       1
# 10978  Step right up to try and taste what juice blen...       0
# 10979  This place is awesome !! Finally I found good ...       2
# 10980  This review is for the customer service. Omg s...       0
# 10981  SO. EXPENSIVE!\nMy carrot cake smoothie was ta...       0
# 10982  Great flavor combinations & love the fact that...       1
# 10983  The ambience is very cool. It has a industrial...       9
# 10984  I saw this place while driving by. I wasn't su...       0
# 10985  Saw that they had happy hour 10% juices so I d...       1
# 10986  I LOVE this place and their juices!  The staff...       4
# 10987  The Greek goddess Demeter heard my call. ORGAN...       1
# 10988  If you haven't tried this place out you NEED t...       0
# 10989  I absolute LOVE this little gem & the gals the...       2
# 10990  I work in the same plaza and I love the dos le...       1
# 10991  Pressed was probably the last juicery I've tri...       1
# 10992  I came in not knowing what to expect.  :) I me...       4
# 10993  Had a little issue yesterday, but the owners a...       0
# 10994  This was my first time here.  I was at work an...       1
# 10995  The smoothies are great however they are ridic...       1
# 10996  If you are too lazy or do not have the 30-60 m...       0
# 10997  I've been meaning to come here for awhile and ...       2
# 10998  I love Pressed for Juice!  Right by my house a...       0
# ...                                                  ...     ...
# 11001  This has got to be the best juice place I've e...       1
# 11002  I took my daughter here for an after school tr...       7
# 11003  Super cute juice bar with the best menu displa...       1
# 11004  A hidden gem on the southwest side.  We love j...       5
# 11005  Friendly and helpful staff. You can sample the...       0
# 11006  A hidden gem on the southwest side.  We love j...       9
# 11007  After following their Instagram account for qu...      10
# 11008  Love this place. They allow you to sample the ...       0
# 11009  Gr8 selection of high quality  fruit and veggi...       0
# 11010  This was my first visit, and I was supeR impre...       2
# 11011  A hidden gem on the southwest side.  We love j...       6
# 11012  Finally a juice spot close by.  Nice interior,...       0
# 11013  I've been here 4 times now, 3 were all within ...       5
# 11014  I really enjoyed my time here.\n\nClean establ...       9
# 11015  My Favorite fresh pressed juice place and they...       1
# 11016  As another reviewer said, this is a true hidde...       7
# 11017  Great place to go to.\n\nWhen I first came int...       1
# 11018  Stopped in here on my way home to grab some mi...       0
# 11019  This place is awesome. It's a very fun experie...       0
# 11020  This place is great.  The staff is very help i...       0
# 11021  They need more cashiers, besides that the juic...       0
# 11022  Stopped by for the first time today and I was ...       0
# 11023  Love love this place, drinks, and staff. The s...       0
# 11024  After living in CA, where you can throw a rock...      18
# 11025  Service and their products are fabulous! Coco ...       0
# 11026  I go 'gaga' for fresh juice of all shapes and ...       9
# 11027  My favorite juice in Vegas!\n\nEverything abou...       4
# 11028  On the east coast, I was drawn to the populari...       7
# 11029  I saw this place while during by. I wasn't sur...       0
# 11030  My favorite juice place in town! I come here o...       0
#
# [62 rows x 12 columns]

# %%
df_item_reset_2.head()
# Out:
#                   user_id             business_id                  name  \
# 0  n_HMBasYWRQxVjts_QyF9w  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 1  tXhscxwFTd-ayLTdPx_2yA  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 2  y4O_c6UUAAtPb3Uk-T4t8A  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 3  _0Za7N9v4rcUVxHy107a7Q  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
# 4  aZg019PkWURjSnC7-CH0Bw  --9e1ONYQuAa-CB_Rrw7Tw  Delmonico Steakhouse
#
#                                         categories  avg_stars  cool  \
# 0  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 1  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 2  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 3  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 4  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
#
#                   date  funny               review_id  stars  \
# 0  2014-03-14 04:56:09      0  7H98TWCrkyRxo8DMfYrWRA    5.0
# 1  2012-05-28 15:40:38      1  jTlP9izKAXbF9T91pbP7RA    3.0
# 2  2017-08-16 06:41:49      0  WYNusZjgf6BsISk829MQKw    5.0
# 3  2015-11-18 21:41:50      0  cHsv7KZDouejMVih43qRUQ    5.0
# 4  2013-05-29 07:23:34      0  CVkTL2dfXOdtpMeFhtWayw    5.0
#
#                                                 text  useful
# 0  this place hasnt change a bit in their service...       0
# 1  I've eaten here twice, it was better a few yea...       0
# 2  A great culinary experience from start to fini...       0
# 3  Had Dinner at Delmonico on 11-5-15.  Still the...       0
# 4  My wife took me here for a fabulous dinner bef...       0

# %%
df_item_reset_2.tail()
# Out:
#                        user_id             business_id       name  \
# 410040  R9Bm86DXed10xMvhJrcDdQ  zzzaIBwimxVej4tY6qFOUQ  Guthrie's
# 410041  BP652XN-JNMhMWzNgZHSRg  zzzaIBwimxVej4tY6qFOUQ  Guthrie's
# 410042  jhaT21VWZVtW2zXPVmzeyg  zzzaIBwimxVej4tY6qFOUQ  Guthrie's
# 410043  mySDXsBhY3u0yI-G2oVDkA  zzzaIBwimxVej4tY6qFOUQ  Guthrie's
# 410044  -gfC7auUsRN2KqTBzHMBZg  zzzaIBwimxVej4tY6qFOUQ  Guthrie's
#
#                    categories  avg_stars  cool                 date  funny  \
# 410040  Southern, Restaurants        3.5     0  2012-12-01 21:13:14      0
# 410041  Southern, Restaurants        3.5     0  2012-12-24 02:19:28      0
# 410042  Southern, Restaurants        3.5     0  2012-11-29 22:13:10      0
# 410043  Southern, Restaurants        3.5     1  2013-02-18 21:37:17      0
# 410044  Southern, Restaurants        3.5     0  2013-06-14 23:17:36      1
#
#                      review_id  stars  \
# 410040  HXN_Lo5hF9gqlFgaBdxkCg    1.0
# 410041  iW5AiBrTtAGgXe3KqANItg    5.0
# 410042  1WgXVPm4FuMQl07COCBtyw    4.0
# 410043  ql4lCsHh45lXZrf4F2S3yg    4.0
# 410044  PBs0VwO7arZqlIba6rAVuA    4.0
#
#                                                      text  useful
# 410040  ordered the 7 strip and the chicken box would ...       2
# 410041  Guthrie's is a great choice for people who are...       2
# 410042  Guthrie's is all about one main thing: chicken...       4
# 410043  I have to say, I do like this place a lot more...       1
# 410044  This is a familiar place to me. I frequented t...       1

# %%
df_item_reset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410045 entries, 0 to 410044
# Data columns (total 12 columns):
# user_id        410045 non-null object
# business_id    410045 non-null object
# name           410045 non-null object
# categories     410045 non-null object
# avg_stars      410045 non-null float64
# cool           410045 non-null int64
# date           410045 non-null object
# funny          410045 non-null int64
# review_id      410045 non-null object
# stars          410045 non-null float64
# text           410045 non-null object
# useful         410045 non-null int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 37.5+ MB

# %%
df_item_reset_2.groupby('user_id').agg('count').min()
# Out:
# business_id    11
# name           11
# categories     11
# avg_stars      11
# cool           11
# date           11
# funny          11
# review_id      11
# stars          11
# text           11
# useful         11
# dtype: int64

# %%
df_item_reset_2.groupby('business_id').agg('count').min()
# Out:
# user_id       8
# name          8
# categories    8
# avg_stars     8
# cool          8
# date          8
# funny         8
# review_id     8
# stars         8
# text          8
# useful        8
# dtype: int64

# %%
len(df_item_reset_2.business_id.unique())
# Out:
# 4218

# %%
len(df_item_reset_2.user_id.unique())
# Out:
# 15801

# %%
df_item_reset_2.to_csv('all_10.csv', index = False)

# %%
item_select_3 = df_item_reset_2['business_id'].value_counts()
df_item_set_3 = df_item_reset_2.set_index('business_id')
df_selected_item = df_item_set_3[item_select_3 > 2]
# Out:
# /Users/Prayerest_/anaconda/envs/python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %%
df_item_reset = df_selected_item.reset_index()
df_item_reset.head()
# Out:
#               business_id                 user_id                  name  \
# 0  --9e1ONYQuAa-CB_Rrw7Tw  SFftbQSwHZ24ahhfj5vVxQ  Delmonico Steakhouse
# 1  --9e1ONYQuAa-CB_Rrw7Tw  joe4i-lcCFd2wViA2agGKw  Delmonico Steakhouse
# 2  --9e1ONYQuAa-CB_Rrw7Tw  n_HMBasYWRQxVjts_QyF9w  Delmonico Steakhouse
# 3  --9e1ONYQuAa-CB_Rrw7Tw  tXhscxwFTd-ayLTdPx_2yA  Delmonico Steakhouse
# 4  --9e1ONYQuAa-CB_Rrw7Tw  azcT4FIP0FCrCwbMQ51HpQ  Delmonico Steakhouse
#
#                                         categories  avg_stars  cool  \
# 0  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 1  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 2  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 3  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
# 4  Cajun/Creole, Seafood, Steakhouses, Restaurants        4.0     0
#
#                  date  funny               review_id  stars  \
# 0 2015-10-23 13:23:34      0  eCJObv4SZupXH5TKWaUhSg    2.0
# 1 2018-05-08 16:39:25      0  tTD3wegtsiHOjVTLgsb7FA    5.0
# 2 2014-03-14 04:56:09      0  7H98TWCrkyRxo8DMfYrWRA    5.0
# 3 2012-05-28 15:40:38      1  jTlP9izKAXbF9T91pbP7RA    3.0
# 4 2013-12-07 01:44:23      0  cKMqmXYq7643CF8rao330w    5.0
#
#                                                 text  useful
# 0  Very busy and noisy restaurant.\nAsparagas was...       0
# 1  On yelp 5 stars = Woohoo! as good as it gets! ...       0
# 2  this place hasnt change a bit in their service...       0
# 3  I've eaten here twice, it was better a few yea...       0
# 4  This is part of my steak house reviews for Las...       2

# %%
df_item_reset.groupby('user_id').agg('count').min()
# Out:
# business_id    3
# name           3
# categories     3
# avg_stars      3
# cool           3
# date           3
# funny          3
# review_id      3
# stars          3
# text           3
# useful         3
# dtype: int64

# %%
df_item_reset.groupby('business_id').agg('count').min()
# Out:
# user_id       3
# name          3
# categories    3
# avg_stars     3
# cool          3
# date          3
# funny         3
# review_id     3
# stars         3
# text          3
# useful        3
# dtype: int64

# %%
df_item_reset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 834551 entries, 0 to 834550
# Data columns (total 12 columns):
# business_id    834551 non-null object
# user_id        834551 non-null object
# name           834551 non-null object
# categories     834551 non-null object
# avg_stars      834551 non-null float64
# cool           834551 non-null int64
# date           834551 non-null datetime64[ns]
# funny          834551 non-null int64
# review_id      834551 non-null object
# stars          834551 non-null float64
# text           834551 non-null object
# useful         834551 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 76.4+ MB

# %%
df_item_reset.to_csv('all_33.csv', index = False)

# %%
df_sort = df_item_reset.sort_values(by='date')

# %%
df_sort.head()
# Out:
#                    business_id                 user_id  \
# 303974  LkMtMHVetws5_7QfRjPtlg  Ud72j_rglYmXrL_O8zCdoA
# 634626  ii8sAGBexBOJoYRFafF9XQ  Ud72j_rglYmXrL_O8zCdoA
# 494972  ZkGDCVKSdf8m76cnnalL-A  Ud72j_rglYmXrL_O8zCdoA
# 453014  Wxxvi3LZbHNIDwJ-ZimtnA  NkVYcoaThHjOfTTgq6OdHQ
# 100660  6xgcHeLad-VaoTIQewK84A  G5LXEaxhQMF_BVjNHkVr7g
#
#                                   name  \
# 303974  LVH - Las Vegas Hotel & Casino
# 634626  Paris Las Vegas Hotel & Casino
# 494972               Le Village Buffet
# 453014          The Venetian Las Vegas
# 100660                 N9NE Steakhouse
#
#                                                categories  avg_stars  cool  \
# 303974  Restaurants, Casinos, Food, Active Life, Night...        2.5     0
# 634626  Restaurants, Hotels, Hotels & Travel, Event Pl...        3.0     0
# 494972  Sandwiches, French, Breakfast & Brunch, Buffet...        3.0     0
# 453014  Shopping Centers, Resorts, Arts & Entertainmen...        4.0     1
# 100660  Seafood, Steakhouses, American (Traditional), ...        4.0     0
#
#                       date  funny               review_id  stars  \
# 303974 2005-01-24 22:21:29      0  Dm7Jh7tVp_97sOxEYH4DnA    4.0
# 634626 2005-01-24 22:32:33      0  VwlljS4oxU4VyP2ODo9gwA    5.0
# 494972 2005-01-26 17:50:53      0  Z54-ssb69Mx_lG1YtJ6N1g    5.0
# 453014 2005-04-22 20:07:39      2  0NmMH1xSUdI3pqed9WQQww    5.0
# 100660 2005-04-27 23:38:05      0  VgBxQqaDgOHq9YRxtMUm3A    5.0
#
#                                                      text  useful
# 303974  This is a little bit off the strip, but the vi...       0
# 634626  The buffet in this hotel is excellent! The set...       0
# 494972  Hella food there!! Cocktail shrimps are great!...       0
# 453014  outstanding hotel. we had a really amazing sui...       2
# 100660  A very reliable source tells me this is the be...       0

# %%
df_sort.to_csv('all_33_date.csv', index = False)
